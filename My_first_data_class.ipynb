# %% [markdown]
# <a href="https://colab.research.google.com/github/kafayatabiodun7-droid/intro-to-data-analysis/blob/main/My_first_data_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("My setup works!")
# Out:
# My setup works!

# %%
print ("Hello world")
# Out:
# Hello world

# %%
Name= "Ada"
Age= 30
Height= 2.65

print(Name,Age,Height)
# Out:
# Ada 30 2.65

# %%
price=20
quantity=4
print(price*quantity)
# Out:
# 80

# %%
selling_price=45
cost_price=18
profit=selling_price-cost_price
profit_margin_percentage=(profit/selling_price)*100
print(profit)
print(profit_margin_percentage)
# Out:
# 27
# 60.0

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ef7af2e0-de53-4e66-a13e-81041c8531f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef7af2e0-de53-4e66-a13e-81041c8531f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
healthcare=pd.read_csv ('healthcare_dataset.csv')
healthcare.head()
# Out:
#    Patient_ID  Age  Gender  Blood_Pressure  Heart_Rate  Cholesterol_Level  \
# 0           1   51  Female              97          90                282
# 1           2   92   Other             129          80                169
# 2           3   14    Male             172          76                157
# 3           4   71  Female             131          82                150
# 4           5   60    Male             130          96                206
#
#     BMI                Diagnosis Treatment_Plan Follow_Up_Date
# 0  35.2             Hypertension    Observation       1/1/2024
# 1  32.3                  Healthy     Medication       1/2/2024
# 2  29.9                 Diabetes    Observation       1/3/2024
# 3  19.4  Coronary Artery Disease        Surgery       1/4/2024
# 4  39.3                 Diabetes            NaN       1/5/2024
